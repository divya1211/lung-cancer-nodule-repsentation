# %%
import torch.utils.data as D
import numpy as np
import torch

# %%
 newtensor = torch.load('nodules.pt')

# %%
# print(newtensor[8].shape)
# sparse = newtensor

# %%
class TensorDataset(D.Dataset):
    def __init__(self, newtensor):
        self.data = newtensor
    def __len__(self):
        return self.data.shape[0]
    def __getitem__(self, index):
        return newtensor[index]

# %%
d = Dataset(newtensor)

loader = torch.utils.data.DataLoader(d, 
                                     batch_size=2,
                                     num_workers=2)

for i in loader:
    print(i.shape)
# Out:
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# torch.Size([2, 50, 50, 50])
# ...
